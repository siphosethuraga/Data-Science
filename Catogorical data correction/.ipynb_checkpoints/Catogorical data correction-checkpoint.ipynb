# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk

# %%
df = pd.read_excel(r'C:\Users\Siphosethu Zothani\Desktop\STAR\Dots Potential Customer Survey Data.xlsx')

# %%
df.describe()
# Out:
#           Unique ID          Age  Annual Family Income ($)  \
# count  3.220000e+03  3220.000000               3220.000000
# mean   4.988139e+06    44.834161              20578.639130
# std    2.867911e+06    19.073161              15079.429422
# min    1.683000e+03    13.000000                 10.000000
# 25%    2.516499e+06    29.000000               8494.000000
# 50%    5.041256e+06    44.000000              16982.000000
# 75%    7.459871e+06    60.000000              30965.250000
# max    9.999011e+06    91.000000              59858.000000
#
#        Time spent watching videos/TV  Time spent playing indoor sports  \
# count                    3220.000000                       3220.000000
# mean                        4.347205                          1.991925
# std                         2.807803                          1.205222
# min                         0.000000                          0.000000
# 25%                         2.000000                          1.000000
# ...

# %%
column_names = df.columns.tolist()
print(column_names)
# Out:
# ['Unique ID', 'Country', 'Age', 'Annual Family Income ($)', 'Gender', 'Time spent watching videos/TV', 'Time spent playing indoor sports', 'Time spent playing outdoor sports', 'Total Time spent working in front of screen', 'Sleeping hours', 'IQ', 'Whether parents have specs', 'English speaker', 'Migrated within country', 'Migrated overseas', 'Maritial Status (0 - Single, 1 - Married, 2 - Divorced)', 'Has Diabetes', 'Education Status', 'Has Gym Subscription', 'Has OTT subscription', 'Number of friends', 'Likes spicy food', 'Likes desserts', 'Wants to change career', 'Has debt', 'Has kids', 'Drinks alcohol', 'Smoker', 'Wear Specs', 'Education Status_encoded', 'Gender_encoded', 'English speaker_encoded']

# %%
columns_to_drop = ['Unique ID', 'Annual Family Income ($)', 'IQ', 'Migrated within country',
                   'Maritial Status (0 - Single, 1 - Married, 2 - Divorced)', 'Education Status',
                   'Number of friends', 'Wants to change career', 'Has debt']

df_cleaned = df.drop(columns=columns_to_drop)

# %%
print(df_cleaned.columns.tolist())
# Out:
# ['Country', 'Age', 'Gender', 'Time spent watching videos/TV', 'Time spent playing indoor sports', 'Time spent playing outdoor sports', 'Total Time spent working in front of screen', 'Sleeping hours', 'Whether parents have specs', 'English speaker', 'Migrated overseas', 'Has Diabetes', 'Has Gym Subscription', 'Has OTT subscription', 'Likes spicy food', 'Likes desserts', 'Has kids', 'Drinks alcohol', 'Smoker', 'Wear Specs', 'Education Status_encoded', 'Gender_encoded', 'English speaker_encoded']

# %%
df_cleaned.describe()
# Out:
#                Age  Time spent watching videos/TV  \
# count  3220.000000                    3220.000000
# mean     44.834161                       4.347205
# std      19.073161                       2.807803
# min      13.000000                       0.000000
# 25%      29.000000                       2.000000
# 50%      44.000000                       4.000000
# 75%      60.000000                       6.000000
# max      91.000000                      10.000000
#
#        Time spent playing indoor sports  Time spent playing outdoor sports  \
# count                       3220.000000                        3220.000000
# mean                           1.991925                           1.700621
# std                            1.205222                           1.190910
# min                            0.000000                          -2.000000
# 25%                            1.000000                           1.000000
# ...
